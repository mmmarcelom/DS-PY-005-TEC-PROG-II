# %% [markdown]
# # Atividade - Aula 1
#
# Para resolver as questões abaixo utilizar o dataset [Titanic](https://github.com/mwaskom/seaborn-data/blob/master/titanic.csv).

# %% [markdown]
# Criar um gráfico com a biblioteca Pandas que mostre a quantidade de pessoas por cidade de embarque, coluna embark_town no dataset.

# %%
import pandas as pd
import seaborn as sns

df_titanic = sns.load_dataset('titanic')
df_titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Questão 1

# %% [markdown]
# Criar um gráfico com a biblioteca Pandas que mostre a quantidade de pessoas por cidade de embarque, coluna embark_town no dataset.

# %%
dados_q1 = df_titanic['embark_town'].value_counts()
dados_q1.head()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
dados_q1.plot.bar(rot=0)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Questão 2

# %% [markdown]
# Criar um gráfico com a biblioteca Pandas que mostre a quantidade de pessoas por cidade de embarque, coluna embark_town no dataset separados pelo sexo, coluna sex no dataset.

# %%
titanic_dummy = pd.get_dummies(df_titanic, columns=['sex'])

dados_q2 = titanic_dummy.groupby('embark_town')[['sex_female', 'sex_male']].sum()
dados_q2.head()
# Out:
#              sex_female  sex_male
# embark_town
# Cherbourg            73        95
# Queenstown           36        41
# Southampton         203       441

# %%
dados_q2.plot.bar(rot=0)
# Out:
# <AxesSubplot: xlabel='embark_town'>

# %% [markdown]
# ## Questão 3
# Criar um gráfico com a biblioteca Pandas que mostre o percentual pelo sexo das pessoas no Titanic.

# %%
dados_q3 = titanic_dummy[['sex_male', 'sex_female']].sum()
dados_q3.head()
# Out:
# sex_male      577
# sex_female    314
# dtype: int64

# %%
dados_q3.plot.pie(subplots=True, autopct ='%.2f%%', colors = ['green', 'red'])
# Out:
# array([<AxesSubplot: >], dtype=object)

# %% [markdown]
# ## Questão 4
# Criar um gráfico com a biblioteca Pandas que mostre os outliers da idade das pessoas no Titanic, coluna age no dataset.

# %%
df_titanic['age'].plot.box()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Questão 5
# Criar um gráfico com a biblioteca Pandas que mostre os outliers da tarifa de embarque das pessoas no Titanic, coluna fare no dataset.

# %%
df_titanic['fare'].plot.box()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Questão 6
# Criar um gráfico com a biblioteca Pandas que mostre a distribuição de idades das pessoas no Titanic, coluna age no dataset.

# %%
df_titanic['age'].plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# ## Questão 7
# Criar um gráfico com a biblioteca Pandas que mostre a distribuição de idades das pessoas no Titanic, coluna age no dataset separados por sexo em dois gráficos.

# %%
dados_qt7 = df_titanic[['sex', 'age']]
dados_qt7.reset_index(inplace=True)
dados_qt7.pivot(index='index',columns='sex', values='age').plot.hist(alpha=0.3)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
dados_qt7.plot.hist(subplots=True)
# Out:
# array([<AxesSubplot: ylabel='Frequency'>,
#        <AxesSubplot: ylabel='Frequency'>], dtype=object)
